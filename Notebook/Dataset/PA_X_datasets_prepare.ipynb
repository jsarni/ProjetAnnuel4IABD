# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
import numpy as np
from random import choice

# %% [markdown]
# ## Dataset split

# %%
data_rep= 'D:\\BUREAU\\corsESGI\\Projet_annuel\\aghylas_juba_merzouk_parts\\'
X_data_rep ="D:\\BUREAU\\corsESGI\\Projet_annuel\\X_datasets_all_parts\\"

dataset_path = 'D:\\BUREAU\\corsESGI\\Projet_annuel\\new_traintest_dataset\\'
train_path= 'D:\\BUREAU\\corsESGI\\Projet_annuel\\new_traintest_dataset\\Train\\'
test_path= 'D:\\BUREAU\\corsESGI\\Projet_annuel\\new_traintest_dataset\\Test\\'
target_path = 'Target\\'
X_data_path = 'X_data\\'




tranche = ['00:00:00-00:30:00','00:30:00-01:00:00','01:00:00-01:30:00','01:30:00-02:00:00','02:00:00-02:30:00','02:30:00-03:00:00','03:00:00-03:30:00','03:30:00-04:00:00','04:00:00-04:30:00','04:30:00-05:00:00','05:00:00-05:30:00','05:30:00-06:00:00','06:00:00-06:30:00','06:30:00-07:00:00','07:00:00-07:30:00','07:30:00-08:00:00','08:00:00-08:30:00','08:30:00-09:00:00','09:00:00-09:30:00','09:30:00-10:00:00','10:00:00-10:30:00','10:30:00-11:00:00','11:00:00-11:30:00','11:30:00-12:00:00','12:00:00-12:30:00','12:30:00-13:00:00','13:00:00-13:30:00','13:30:00-14:00:00','14:00:00-14:30:00','14:30:00-15:00:00','15:00:00-15:30:00','15:30:00-16:00:00','16:00:00-16:30:00','16:30:00-17:00:00','17:00:00-17:30:00','17:30:00-18:00:00','18:00:00-18:30:00','18:30:00-19:00:00','19:00:00-19:30:00','19:30:00-20:00:00','20:00:00-20:30:00','20:30:00-21:00:00','21:00:00-21:30:00','21:30:00-22:00:00','22:00:00-22:30:00','22:30:00-23:00:00','23:00:00-23:30:00','23:30:00-00:00:00']



Y_data_files=[f for f in listdir(data_rep) if isfile(join(data_rep, f))]
Y_data_files.sort(key=len)

X_data_files=[f for f in listdir(X_data_rep) if isfile(join(X_data_rep, f))]
X_data_files.sort(key=len)

# print(Y_data_files[0],X_data_files[0])

# df_nb_palaces = pd.read_csv("D:\\BUREAU\\corsESGI\\Projet_annuel\\capacites_horodateurs_2.csv",sep=';')


def dataset_split():
    for i in range(len(X_data_files)):
        df = pd.read_csv(data_rep+Y_data_files[i], sep=';')
        rr=df[tranche].copy()
        list_ind=rr[rr.sum(axis=1) ==0].index.tolist()
        list_ind  = [ i for i in list_ind if i > 365]
        rr=rr[~rr.index.isin(list_ind)]
        gg=pd.DataFrame(data=rr[tranche].values.reshape((len(rr)*48),1).flatten().T,columns=['Target'])
        last_index = gg.index[-1]
        
        x_df=pd.read_csv(X_data_rep+X_data_files[i], sep=';')
        list_ind=x_df.index.tolist()
        list_ind  = [ i for i in list_ind if i <= last_index]

        x_df=x_df[x_df.index.isin(list_ind)]
        
        dataset=pd.concat([x_df,gg],axis=1)
        dataset=dataset.sample(frac=1)
        
        train_dataset = dataset.sample(frac=0.8,random_state=0)
        test_dataset = dataset.drop(train_dataset.index)
        train_labels = train_dataset.pop('Target')
        test_labels = test_dataset.pop('Target')
        
        train_labels =train_labels.apply(lambda x : train_labels.values.max() -x) 
        test_labels =test_labels.apply(lambda x : test_labels.values.max() -x) 
        
    
        
        train_dataset.to_csv(train_path+X_data_path+Y_data_files[i],index=False,sep=';')
        train_labels.to_csv(train_path+target_path+Y_data_files[i],index=False,sep=';')
        test_dataset.to_csv(test_path+X_data_path+Y_data_files[i],index=False,sep=';')
        test_labels.to_csv(test_path+target_path+Y_data_files[i],index=False,sep=';')
        
#         y_last=res['Target'].to_frame()
        
#         y_last.to_csv(joined_Y_data_rep+Y_data_files[i],index=False,sep=';')
        
#         x_columns=res.columns.values.tolist()[:-1]
#         x_last =res[x_columns]
        
#         x_last.to_csv(joined_X_data_rep+Y_data_files[i],index=False,sep=';')
        

        print( 'file : ', i+1,'/', len(Y_data_files))
        i=i+1
        
        
    
    
# dataset_split()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-281520645937> in <module>
#      15
#      16
# ---> 17 Y_data_files=[f for f in listdir(data_rep) if isfile(join(data_rep, f))]
#      18 Y_data_files.sort(key=len)
#      19
#
# NameError: name 'listdir' is not defined

# %% [markdown]
# ## X train batch

# %%
dataset_path = 'D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\'
dataset_batch_path = 'D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\'
train_path= 'D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Train\\'
test_path= 'D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\test\\'
target_path = 'Target\\'
X_data_path = 'X_data\\'

# %%
files = [f for f in listdir( train_path+ X_data_path) if isfile(join(train_path+ X_data_path, f))]
files.sort(key=len)


def train_x_batch():
    i=1
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\X_data\\X_batch_0.csv', 'a') as f:
        for e in files [:1300]:
            df = pd.read_csv (train_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 0 file : ', i,'/', len(files))
            i=i+1
    
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\X_data\\X_batch_1.csv', 'a') as f:
        for e in files [1300 : 2600]:
            df = pd.read_csv (train_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 1 file : ', i,'/', len(files))
            i=i+1
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\X_data\\X_batch_2.csv', 'a') as f:
        for e in files [ 2600:3900]:
            df = pd.read_csv (train_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 2 file : ', i,'/', len(files))
            i=i+1
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\X_data\\X_batch_3.csv', 'a') as f:
        for e in files [ 3900:5200]:
            df = pd.read_csv (train_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 3 file : ', i,'/', len(files))
            i=i+1
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\X_data\\X_batch_4.csv', 'a') as f:
        for e in files [ 5200:6500]:
            df = pd.read_csv (train_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 4 file : ', i,'/', len(files))
            i=i+1
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\X_data\\X_batch_5.csv', 'a') as f:
        for e in files [ 6500:]:
            df = pd.read_csv (train_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 5 file : ', i,'/', len(files))
            i=i+1


    
train_x_batch()
# Out:
# batch 0 file :  1 / 7801
# batch 0 file :  2 / 7801
# batch 0 file :  3 / 7801
# batch 0 file :  4 / 7801
# batch 0 file :  5 / 7801
# batch 0 file :  6 / 7801
# batch 0 file :  7 / 7801
# batch 0 file :  8 / 7801
# batch 0 file :  9 / 7801
# batch 0 file :  10 / 7801
# batch 0 file :  11 / 7801
# batch 0 file :  12 / 7801
# batch 0 file :  13 / 7801
# batch 0 file :  14 / 7801
# batch 0 file :  15 / 7801
# batch 0 file :  16 / 7801
# batch 0 file :  17 / 7801
# batch 0 file :  18 / 7801
# batch 0 file :  19 / 7801
# batch 0 file :  20 / 7801
# batch 0 file :  21 / 7801
# batch 0 file :  22 / 7801
# batch 0 file :  23 / 7801
# batch 0 file :  24 / 7801
# batch 0 file :  25 / 7801
# batch 0 file :  26 / 7801
# batch 0 file :  27 / 7801
# batch 0 file :  28 / 7801
# batch 0 file :  29 / 7801
# batch 0 file :  30 / 7801
# batch 0 file :  31 / 7801
# batch 0 file :  32 / 7801
# batch 0 file :  33 / 7801
# batch 0 file :  34 / 7801
# batch 0 file :  35 / 7801
# batch 0 file :  36 / 7801
# ...

# %% [markdown]
# ## Target train batch

# %%
files = [f for f in listdir( train_path+ target_path) if isfile(join(train_path+ target_path, f))]
files.sort(key=len)


def train_target_batch():
    i=1
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\Target\\Target_batch_0.csv', 'a') as f:
        for e in files [:1300]:
            df = pd.read_csv (train_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 0 file : ', i,'/', len(files))
            i=i+1
    
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\Target\\Target_batch_1.csv', 'a') as f:
        for e in files [1300 : 2600]:
            df = pd.read_csv (train_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 1 file : ', i,'/', len(files))
            i=i+1
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\Target\\Target_batch_2.csv', 'a') as f:
        for e in files [ 2600:3900]:
            df = pd.read_csv (train_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 2 file : ', i,'/', len(files))
            i=i+1   
    
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\Target\\Target_batch_3.csv', 'a') as f:
        for e in files [ 3900:5200]:
            df = pd.read_csv (train_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 3 file : ', i,'/', len(files))
            i=i+1 
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\Target\\Target_batch_4.csv', 'a') as f:
        for e in files [ 5200:6500]:
            df = pd.read_csv (train_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 4 file : ', i,'/', len(files))
            i=i+1 
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\Target\\Target_batch_5.csv', 'a') as f:
        for e in files [ 6500:]:
            df = pd.read_csv (train_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 5 file : ', i,'/', len(files))
            i=i+1   
            
                 
            
            
train_target_batch()
# Out:
# batch 0 file :  1 / 7801
# batch 0 file :  2 / 7801
# batch 0 file :  3 / 7801
# batch 0 file :  4 / 7801
# batch 0 file :  5 / 7801
# batch 0 file :  6 / 7801
# batch 0 file :  7 / 7801
# batch 0 file :  8 / 7801
# batch 0 file :  9 / 7801
# batch 0 file :  10 / 7801
# batch 0 file :  11 / 7801
# batch 0 file :  12 / 7801
# batch 0 file :  13 / 7801
# batch 0 file :  14 / 7801
# batch 0 file :  15 / 7801
# batch 0 file :  16 / 7801
# batch 0 file :  17 / 7801
# batch 0 file :  18 / 7801
# batch 0 file :  19 / 7801
# batch 0 file :  20 / 7801
# batch 0 file :  21 / 7801
# batch 0 file :  22 / 7801
# batch 0 file :  23 / 7801
# batch 0 file :  24 / 7801
# batch 0 file :  25 / 7801
# batch 0 file :  26 / 7801
# batch 0 file :  27 / 7801
# batch 0 file :  28 / 7801
# batch 0 file :  29 / 7801
# batch 0 file :  30 / 7801
# batch 0 file :  31 / 7801
# batch 0 file :  32 / 7801
# batch 0 file :  33 / 7801
# batch 0 file :  34 / 7801
# batch 0 file :  35 / 7801
# batch 0 file :  36 / 7801
# ...

# %% [markdown]
# ## X test batch

# %%
files = [f for f in listdir( test_path+ X_data_path) if isfile(join(test_path+ X_data_path, f))]
files.sort(key=len)


def test_x_batch():
    i=1
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\X_data\\X_batch_0.csv', 'a') as f:
        for e in files [:1300]:
            df = pd.read_csv (test_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 0 file : ', i,'/', len(files))
            i=i+1
    
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\X_data\\X_batch_1.csv', 'a') as f:
        for e in files [1300 : 2600]:
            df = pd.read_csv (test_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 1 file : ', i,'/', len(files))
            i=i+1
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\X_data\\X_batch_2.csv', 'a') as f:
        for e in files [ 2600:3900]:
            df = pd.read_csv (test_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 2 file : ', i,'/', len(files))
            i=i+1
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\X_data\\X_batch_3.csv', 'a') as f:
        for e in files [ 3900:5200]:
            df = pd.read_csv (test_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 3 file : ', i,'/', len(files))
            i=i+1
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\X_data\\X_batch_4.csv', 'a') as f:
        for e in files [ 5200:6500]:
            df = pd.read_csv (test_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 4 file : ', i,'/', len(files))
            i=i+1
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\X_data\\X_batch_5.csv', 'a') as f:
        for e in files [ 6500:]:
            df = pd.read_csv (test_path+ X_data_path +e, sep=';' )
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 5 file : ', i,'/', len(files))
            i=i+1

test_x_batch()
# Out:
# batch 0 file :  1 / 7801
# batch 0 file :  2 / 7801
# batch 0 file :  3 / 7801
# batch 0 file :  4 / 7801
# batch 0 file :  5 / 7801
# batch 0 file :  6 / 7801
# batch 0 file :  7 / 7801
# batch 0 file :  8 / 7801
# batch 0 file :  9 / 7801
# batch 0 file :  10 / 7801
# batch 0 file :  11 / 7801
# batch 0 file :  12 / 7801
# batch 0 file :  13 / 7801
# batch 0 file :  14 / 7801
# batch 0 file :  15 / 7801
# batch 0 file :  16 / 7801
# batch 0 file :  17 / 7801
# batch 0 file :  18 / 7801
# batch 0 file :  19 / 7801
# batch 0 file :  20 / 7801
# batch 0 file :  21 / 7801
# batch 0 file :  22 / 7801
# batch 0 file :  23 / 7801
# batch 0 file :  24 / 7801
# batch 0 file :  25 / 7801
# batch 0 file :  26 / 7801
# batch 0 file :  27 / 7801
# batch 0 file :  28 / 7801
# batch 0 file :  29 / 7801
# batch 0 file :  30 / 7801
# batch 0 file :  31 / 7801
# batch 0 file :  32 / 7801
# batch 0 file :  33 / 7801
# batch 0 file :  34 / 7801
# batch 0 file :  35 / 7801
# batch 0 file :  36 / 7801
# ...

# %% [markdown]
# ## Target test batch

# %%
files = [f for f in listdir( test_path+ target_path) if isfile(join(test_path+ target_path, f))]
files.sort(key=len)


def test_target_batch():
    i=1
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\Target\\Target_batch_0.csv', 'a') as f:
        for e in files [:2600]:
            df = pd.read_csv (test_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 0 file : ', i,'/', len(files))
            i=i+1
    
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\Target\\Target_batch_1.csv', 'a') as f:
        for e in files [1300 : 2600]:
            df = pd.read_csv (test_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 1 file : ', i,'/', len(files))
            i=i+1
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\Target\\Target_batch_2.csv', 'a') as f:
        for e in files [ 2600:3900]:
            df = pd.read_csv (test_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 2 file : ', i,'/', len(files))
            i=i+1   
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\Target\\Target_batch_3.csv', 'a') as f:
        for e in files [ 3900:5200]:
            df = pd.read_csv (test_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 3 file : ', i,'/', len(files))
            i=i+1  
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\Target\\Target_batch_4.csv', 'a') as f:
        for e in files [ 5200:6500]:
            df = pd.read_csv (test_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 4 file : ', i,'/', len(files))
            i=i+1
            
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Test\\Target\\Target_batch_5.csv', 'a') as f:
        for e in files [ 6500:]:
            df = pd.read_csv (test_path+ target_path +e, sep=';' )
            df = df.apply(lambda x : df.values.max() -x)
            df.to_csv(f,header=False, line_terminator='\n')
            print( 'batch 5 file : ', i,'/', len(files))
            i=i+1

test_target_batch()
# Out:
# batch 0 file :  1 / 7801
# batch 0 file :  2 / 7801
# batch 0 file :  3 / 7801
# batch 0 file :  4 / 7801
# batch 0 file :  5 / 7801
# batch 0 file :  6 / 7801
# batch 0 file :  7 / 7801
# batch 0 file :  8 / 7801
# batch 0 file :  9 / 7801
# batch 0 file :  10 / 7801
# batch 0 file :  11 / 7801
# batch 0 file :  12 / 7801
# batch 0 file :  13 / 7801
# batch 0 file :  14 / 7801
# batch 0 file :  15 / 7801
# batch 0 file :  16 / 7801
# batch 0 file :  17 / 7801
# batch 0 file :  18 / 7801
# batch 0 file :  19 / 7801
# batch 0 file :  20 / 7801
# batch 0 file :  21 / 7801
# batch 0 file :  22 / 7801
# batch 0 file :  23 / 7801
# batch 0 file :  24 / 7801
# batch 0 file :  25 / 7801
# batch 0 file :  26 / 7801
# batch 0 file :  27 / 7801
# batch 0 file :  28 / 7801
# batch 0 file :  29 / 7801
# batch 0 file :  30 / 7801
# batch 0 file :  31 / 7801
# batch 0 file :  32 / 7801
# batch 0 file :  33 / 7801
# batch 0 file :  34 / 7801
# batch 0 file :  35 / 7801
# batch 0 file :  36 / 7801
# ...

# %% [markdown]
# ## Create Dataset ( train / test) with 240 random files on 7801 and generate pickled files

# %%
import pickle

data_rep= 'D:\\BUREAU\\corsESGI\\Projet_annuel\\aghylas_juba_merzouk_parts\\'
X_data_rep ="D:\\BUREAU\\corsESGI\\Projet_annuel\\X_datasets_all_parts\\"

dataset_path = 'D:\\BUREAU\\corsESGI\\Projet_annuel\\pickeled\\'
train_path= 'D:\\BUREAU\\corsESGI\\Projet_annuel\\pickeled\\Train\\'
test_path= 'D:\\BUREAU\\corsESGI\\Projet_annuel\\pickeled\\Test\\'
target_path = 'Target\\'
X_data_path = 'X_data\\'




tranche = ['00:00:00-00:30:00','00:30:00-01:00:00','01:00:00-01:30:00','01:30:00-02:00:00','02:00:00-02:30:00','02:30:00-03:00:00','03:00:00-03:30:00','03:30:00-04:00:00','04:00:00-04:30:00','04:30:00-05:00:00','05:00:00-05:30:00','05:30:00-06:00:00','06:00:00-06:30:00','06:30:00-07:00:00','07:00:00-07:30:00','07:30:00-08:00:00','08:00:00-08:30:00','08:30:00-09:00:00','09:00:00-09:30:00','09:30:00-10:00:00','10:00:00-10:30:00','10:30:00-11:00:00','11:00:00-11:30:00','11:30:00-12:00:00','12:00:00-12:30:00','12:30:00-13:00:00','13:00:00-13:30:00','13:30:00-14:00:00','14:00:00-14:30:00','14:30:00-15:00:00','15:00:00-15:30:00','15:30:00-16:00:00','16:00:00-16:30:00','16:30:00-17:00:00','17:00:00-17:30:00','17:30:00-18:00:00','18:00:00-18:30:00','18:30:00-19:00:00','19:00:00-19:30:00','19:30:00-20:00:00','20:00:00-20:30:00','20:30:00-21:00:00','21:00:00-21:30:00','21:30:00-22:00:00','22:00:00-22:30:00','22:30:00-23:00:00','23:00:00-23:30:00','23:30:00-00:00:00']



Y_data_files=[f for f in listdir(data_rep) if isfile(join(data_rep, f))]
Y_data_files.sort(key=len)

X_data_files=[f for f in listdir(X_data_rep) if isfile(join(X_data_rep, f))]
X_data_files.sort(key=len)

# print(Y_data_files[0],X_data_files[0])

# df_nb_palaces = pd.read_csv("D:\\BUREAU\\corsESGI\\Projet_annuel\\capacites_horodateurs_2.csv",sep=';')


def dataset_split():
    res_data =pd.DataFrame(columns=['Latitude', 'Longitude', 'day_of_week', 'month' ,'00:00:00-00:30:00'
 ,'00:30:00-01:00:00' ,'01:00:00-01:30:00' ,'01:30:00-02:00:00'
 ,'02:00:00-02:30:00' ,'02:30:00-03:00:00' ,'03:00:00-03:30:00'
 ,'03:30:00-04:00:00' ,'04:00:00-04:30:00' ,'04:30:00-05:00:00'
 ,'05:00:00-05:30:00' ,'05:30:00-06:00:00' ,'06:00:00-06:30:00'
 ,'06:30:00-07:00:00' ,'07:00:00-07:30:00' ,'07:30:00-08:00:00'
 ,'08:00:00-08:30:00' ,'08:30:00-09:00:00' ,'09:00:00-09:30:00'
 ,'09:30:00-10:00:00' ,'10:00:00-10:30:00' ,'10:30:00-11:00:00'
 ,'11:00:00-11:30:00' ,'11:30:00-12:00:00' ,'12:00:00-12:30:00'
 ,'12:30:00-13:00:00' ,'13:00:00-13:30:00' ,'13:30:00-14:00:00'
 ,'14:00:00-14:30:00' ,'14:30:00-15:00:00' ,'15:00:00-15:30:00'
 ,'15:30:00-16:00:00' ,'16:00:00-16:30:00' ,'16:30:00-17:00:00'
 ,'17:00:00-17:30:00' ,'17:30:00-18:00:00' ,'18:00:00-18:30:00'
 ,'18:30:00-19:00:00' ,'19:00:00-19:30:00' ,'19:30:00-20:00:00'
 ,'20:00:00-20:30:00' ,'20:30:00-21:00:00' ,'21:00:00-21:30:00'
 ,'21:30:00-22:00:00' ,'22:00:00-22:30:00' ,'22:30:00-23:00:00'
 ,'23:00:00-23:30:00' ,'23:30:00-00:00:00' ,'Target'])
    train_indexes = [z for z in range(len(X_data_files))]
    
    for i in range(200):
        ind=choice(train_indexes)
        df = pd.read_csv(data_rep+Y_data_files[ind], sep=';')
        rr=df[tranche].copy()
        list_ind=rr[rr.sum(axis=1) ==0].index.tolist()
        list_ind  = [ i for i in list_ind if i > 365]
        rr=rr[~rr.index.isin(list_ind)]
        gg=pd.DataFrame(data=rr[tranche].values.reshape((len(rr)*48),1).flatten().T,columns=['Target'])
        gg.apply(lambda x : gg.values.max() -x)
        last_index = gg.index[-1]
        
        x_df=pd.read_csv(X_data_rep+X_data_files[ind], sep=';')
        list_ind=x_df.index.tolist()
        list_ind  = [ j for j in list_ind if j <= last_index]

        x_df=x_df[x_df.index.isin(list_ind)]
        
        dataset=pd.concat([x_df,gg],axis=1)
        res_data= pd.concat([res_data,dataset],ignore_index=True)
        print( 'file : ', i+1,'/ 200')
        i=i+1
    
    res=res_data.sample(frac=1)
        

        

    train_dataset = res.sample(frac=0.8,random_state=0)
    test_dataset = res.drop(train_dataset.index)
    train_labels = train_dataset.pop('Target')
    test_labels = test_dataset.pop('Target')





    train_dataset.to_csv(train_path+X_data_path+'X_random_240_bis.csv',index=False,sep=';')
    train_labels.to_csv(train_path+target_path+'Y_random_240_bis.csv',index=False,sep=';')
    test_dataset.to_csv(test_path+X_data_path+'X_random_240_bis.csv',index=False,sep=';')
    test_labels.to_csv(test_path+target_path+'Y_random_240_bis.csv',index=False,sep=';')
    
    with open (train_path+X_data_path+'X_random_100_pickeled', 'wb' ) as f :
        pickle.dump( train_dataset.values,f)
        
    with open (train_path+target_path+'Y_random_100_pickeled', 'wb' ) as f :
        pickle.dump( train_labels.values,f)
        
    with open (test_path+X_data_path+'X_random_100_pickeled', 'wb' ) as f :
        pickle.dump( test_dataset.values,f)
        
    with open (test_path+target_path+'Y_random_100_pickeled', 'wb' ) as f :
        pickle.dump( test_labels.values,f)

# %% [markdown]
# ## Joining data

# %%
joined_Y_data_rep = 'D:\\BUREAU\\corsESGI\\Projet_annuel\\X_dataset_joined\\'
data_rep = 'D:\\BUREAU\\corsESGI\\Projet_annuel\\X_datasets_all_parts\\' 
tranche = ['00:00:00-00:30:00','00:30:00-01:00:00','01:00:00-01:30:00','01:30:00-02:00:00','02:00:00-02:30:00','02:30:00-03:00:00','03:00:00-03:30:00','03:30:00-04:00:00','04:00:00-04:30:00','04:30:00-05:00:00','05:00:00-05:30:00','05:30:00-06:00:00','06:00:00-06:30:00','06:30:00-07:00:00','07:00:00-07:30:00','07:30:00-08:00:00','08:00:00-08:30:00','08:30:00-09:00:00','09:00:00-09:30:00','09:30:00-10:00:00','10:00:00-10:30:00','10:30:00-11:00:00','11:00:00-11:30:00','11:30:00-12:00:00','12:00:00-12:30:00','12:30:00-13:00:00','13:00:00-13:30:00','13:30:00-14:00:00','14:00:00-14:30:00','14:30:00-15:00:00','15:00:00-15:30:00','15:30:00-16:00:00','16:00:00-16:30:00','16:30:00-17:00:00','17:00:00-17:30:00','17:30:00-18:00:00','18:00:00-18:30:00','18:30:00-19:00:00','19:00:00-19:30:00','19:30:00-20:00:00','20:00:00-20:30:00','20:30:00-21:00:00','21:00:00-21:30:00','21:30:00-22:00:00','22:00:00-22:30:00','22:30:00-23:00:00','23:00:00-23:30:00','23:30:00-00:00:00']

X_data_files=[f for f in listdir(data_rep) if isfile(join(data_rep, f))]
X_data_files.sort(key=len)

#  for normal dataset
# ll= ['horodateur','Longitude','Latitude','date','day_of_week','00:00:00-00:30:00','00:30:00-01:00:00','01:00:00-01:30:00','01:30:00-02:00:00','02:00:00-02:30:00','02:30:00-03:00:00','03:00:00-03:30:00','03:30:00-04:00:00','04:00:00-04:30:00','04:30:00-05:00:00','05:00:00-05:30:00','05:30:00-06:00:00','06:00:00-06:30:00','06:30:00-07:00:00','07:00:00-07:30:00','07:30:00-08:00:00','08:00:00-08:30:00','08:30:00-09:00:00','09:00:00-09:30:00','09:30:00-10:00:00','10:00:00-10:30:00','10:30:00-11:00:00','11:00:00-11:30:00','11:30:00-12:00:00','12:00:00-12:30:00','12:30:00-13:00:00','13:00:00-13:30:00','13:30:00-14:00:00','14:00:00-14:30:00','14:30:00-15:00:00','15:00:00-15:30:00','15:30:00-16:00:00','16:00:00-16:30:00','16:30:00-17:00:00','17:00:00-17:30:00','17:30:00-18:00:00','18:00:00-18:30:00','18:30:00-19:00:00','19:00:00-19:30:00','19:30:00-20:00:00','20:00:00-20:30:00','20:30:00-21:00:00','21:00:00-21:30:00','21:30:00-22:00:00','22:00:00-22:30:00','22:30:00-23:00:00','23:00:00-23:30:00','23:30:00-00:00:00']
#  for x dataset
ll= ['Latitude','Longitude','day_of_week','month','00:00:00-00:30:00','00:30:00-01:00:00','01:00:00-01:30:00','01:30:00-02:00:00','02:00:00-02:30:00','02:30:00-03:00:00','03:00:00-03:30:00','03:30:00-04:00:00','04:00:00-04:30:00','04:30:00-05:00:00','05:00:00-05:30:00','05:30:00-06:00:00','06:00:00-06:30:00','06:30:00-07:00:00','07:00:00-07:30:00','07:30:00-08:00:00','08:00:00-08:30:00','08:30:00-09:00:00','09:00:00-09:30:00','09:30:00-10:00:00','10:00:00-10:30:00','10:30:00-11:00:00','11:00:00-11:30:00','11:30:00-12:00:00','12:00:00-12:30:00','12:30:00-13:00:00','13:00:00-13:30:00','13:30:00-14:00:00','14:00:00-14:30:00','14:30:00-15:00:00','15:00:00-15:30:00','15:30:00-16:00:00','16:00:00-16:30:00','16:30:00-17:00:00','17:00:00-17:30:00','17:30:00-18:00:00','18:00:00-18:30:00','18:30:00-19:00:00','19:00:00-19:30:00','19:30:00-20:00:00','20:00:00-20:30:00','20:30:00-21:00:00','21:00:00-21:30:00','21:30:00-22:00:00','22:00:00-22:30:00','22:30:00-23:00:00','23:00:00-23:30:00','23:30:00-00:00:00']

res = pd.DataFrame(columns =ll)

def join_X_data():
    with open('D:\\BUREAU\\corsESGI\\Projet_annuel\\X_dataset_joined\\Last_X_dataset_all_parts.csv', 'a') as f:
        i=1
        for e in data_files[1904:]:
            df = pd.read_csv(data_rep+e, sep=';')
            df.to_csv(f, header=False)
#             res = pd.concat([res,df], ignore_index=True)
            print( 'file : ', i,'/', len(data_files))
            i=i+1
#     res = res[tranche]
#     res.to_csv(joined_Y_data_rep+"Last_X_dataset_all_parts.csv",index=False,sep=';')
    
join_X_data()
# Out:
# file :  1 / 7801
# file :  2 / 7801
# file :  3 / 7801
# file :  4 / 7801
# file :  5 / 7801
# file :  6 / 7801
# file :  7 / 7801
# file :  8 / 7801
# file :  9 / 7801
# file :  10 / 7801
# file :  11 / 7801
# file :  12 / 7801
# file :  13 / 7801
# file :  14 / 7801
# file :  15 / 7801
# file :  16 / 7801
# file :  17 / 7801
# file :  18 / 7801
# file :  19 / 7801
# file :  20 / 7801
# file :  21 / 7801
# file :  22 / 7801
# file :  23 / 7801
# file :  24 / 7801
# file :  25 / 7801
# file :  26 / 7801
# file :  27 / 7801
# file :  28 / 7801
# file :  29 / 7801
# file :  30 / 7801
# file :  31 / 7801
# file :  32 / 7801
# file :  33 / 7801
# file :  34 / 7801
# file :  35 / 7801
# file :  36 / 7801
# file :  37 / 7801
# file :  38 / 7801
# file :  39 / 7801
# file :  40 / 7801
# file :  41 / 7801
# file :  42 / 7801
# file :  43 / 7801
# file :  44 / 7801
# file :  45 / 7801
# file :  46 / 7801
# file :  47 / 7801
# file :  48 / 7801
# file :  49 / 7801
# file :  50 / 7801
# ...

# %%
# fonction création X_datasets

def get_xtrain(dataset):

    tranche = ['00:00:00-00:30:00','00:30:00-01:00:00','01:00:00-01:30:00','01:30:00-02:00:00','02:00:00-02:30:00','02:30:00-03:00:00','03:00:00-03:30:00','03:30:00-04:00:00','04:00:00-04:30:00','04:30:00-05:00:00','05:00:00-05:30:00','05:30:00-06:00:00','06:00:00-06:30:00','06:30:00-07:00:00','07:00:00-07:30:00','07:30:00-08:00:00','08:00:00-08:30:00','08:30:00-09:00:00','09:00:00-09:30:00','09:30:00-10:00:00','10:00:00-10:30:00','10:30:00-11:00:00','11:00:00-11:30:00','11:30:00-12:00:00','12:00:00-12:30:00','12:30:00-13:00:00','13:00:00-13:30:00','13:30:00-14:00:00','14:00:00-14:30:00','14:30:00-15:00:00','15:00:00-15:30:00','15:30:00-16:00:00','16:00:00-16:30:00','16:30:00-17:00:00','17:00:00-17:30:00','17:30:00-18:00:00','18:00:00-18:30:00','18:30:00-19:00:00','19:00:00-19:30:00','19:30:00-20:00:00','20:00:00-20:30:00','20:30:00-21:00:00','21:00:00-21:30:00','21:30:00-22:00:00','22:00:00-22:30:00','22:30:00-23:00:00','23:00:00-23:30:00','23:30:00-00:00:00']

    df_horo_day=dataset[["Latitude","Longitude","day_of_week","date"]].copy()
    df_horo_day['month']= df_horo_day['date'].apply(lambda x : pd.to_datetime(x).month )
    del df_horo_day['date']

    df_horo_day[["day_of_week","month"]]=df_horo_day[["day_of_week","month"]].astype(int)

    df_horo_day_last=df_horo_day.iloc[0:0]
    for index,row in df_horo_day.iterrows():
        df_horo_day_last=df_horo_day_last.append([row]*48,ignore_index=True)



    test=pd.DataFrame(np.identity(48),columns=tranche)
    test=test.astype(int)
    test=test.append([test]*(len(df_horo_day)-1),ignore_index=True)

    df_horo_day_last[test.columns.tolist()]=test
    df_horo_day_last[["day_of_week","month"]] = df_horo_day_last[["day_of_week","month"]].astype(int)

    return df_horo_day_last

# %%
# Création des X_datatsets


monRepertoire = 'D:\\BUREAU\corsESGI\\Projet_annuel\\aghylas_juba_parts\\'
X_data_rep = "D:\\BUREAU\\corsESGI\\Projet_annuel\\X_datasets\\"

tranche = ['00:00:00-00:30:00','00:30:00-01:00:00','01:00:00-01:30:00','01:30:00-02:00:00','02:00:00-02:30:00','02:30:00-03:00:00','03:00:00-03:30:00','03:30:00-04:00:00','04:00:00-04:30:00','04:30:00-05:00:00','05:00:00-05:30:00','05:30:00-06:00:00','06:00:00-06:30:00','06:30:00-07:00:00','07:00:00-07:30:00','07:30:00-08:00:00','08:00:00-08:30:00','08:30:00-09:00:00','09:00:00-09:30:00','09:30:00-10:00:00','10:00:00-10:30:00','10:30:00-11:00:00','11:00:00-11:30:00','11:30:00-12:00:00','12:00:00-12:30:00','12:30:00-13:00:00','13:00:00-13:30:00','13:30:00-14:00:00','14:00:00-14:30:00','14:30:00-15:00:00','15:00:00-15:30:00','15:30:00-16:00:00','16:00:00-16:30:00','16:30:00-17:00:00','17:00:00-17:30:00','17:30:00-18:00:00','18:00:00-18:30:00','18:30:00-19:00:00','19:00:00-19:30:00','19:30:00-20:00:00','20:00:00-20:30:00','20:30:00-21:00:00','21:00:00-21:30:00','21:30:00-22:00:00','22:00:00-22:30:00','22:30:00-23:00:00','23:00:00-23:30:00','23:30:00-00:00:00']

fichiers = [f for f in listdir(monRepertoire) if isfile(join(monRepertoire, f))]
fichiers.sort(key=len)
ll= ['horodateur','Longitude','Latitude','date','day_of_week','00:00:00-00:30:00','00:30:00-01:00:00','01:00:00-01:30:00','01:30:00-02:00:00','02:00:00-02:30:00','02:30:00-03:00:00','03:00:00-03:30:00','03:30:00-04:00:00','04:00:00-04:30:00','04:30:00-05:00:00','05:00:00-05:30:00','05:30:00-06:00:00','06:00:00-06:30:00','06:30:00-07:00:00','07:00:00-07:30:00','07:30:00-08:00:00','08:00:00-08:30:00','08:30:00-09:00:00','09:00:00-09:30:00','09:30:00-10:00:00','10:00:00-10:30:00','10:30:00-11:00:00','11:00:00-11:30:00','11:30:00-12:00:00','12:00:00-12:30:00','12:30:00-13:00:00','13:00:00-13:30:00','13:30:00-14:00:00','14:00:00-14:30:00','14:30:00-15:00:00','15:00:00-15:30:00','15:30:00-16:00:00','16:00:00-16:30:00','16:30:00-17:00:00','17:00:00-17:30:00','17:30:00-18:00:00','18:00:00-18:30:00','18:30:00-19:00:00','19:00:00-19:30:00','19:30:00-20:00:00','20:00:00-20:30:00','20:30:00-21:00:00','21:00:00-21:30:00','21:30:00-22:00:00','22:00:00-22:30:00','22:30:00-23:00:00','23:00:00-23:30:00','23:30:00-00:00:00']
res = pd.DataFrame(columns =ll)

def read_dataset(res):
    i=1
    for e in fichiers:
        df = pd.read_csv(monRepertoire+e, sep=';')
        res = get_xtrain(df)
        res.to_csv(X_data_rep+"X_" +e,index=False,sep=';')
        print( 'file : ', i,'/', len(fichiers))
        i=i+1
        
    

read_dataset(res)
# Out:
# file :  1 / 5199
# file :  2 / 5199
# file :  3 / 5199
# file :  4 / 5199
# file :  5 / 5199
# file :  6 / 5199
# file :  7 / 5199
# file :  8 / 5199
# file :  9 / 5199
# file :  10 / 5199
# file :  11 / 5199
# file :  12 / 5199
# file :  13 / 5199
# file :  14 / 5199
# file :  15 / 5199
# file :  16 / 5199
# file :  17 / 5199
# file :  18 / 5199
# file :  19 / 5199
# file :  20 / 5199
# file :  21 / 5199
# file :  22 / 5199
# file :  23 / 5199
# file :  24 / 5199
# file :  25 / 5199
# file :  26 / 5199
# file :  27 / 5199
# file :  28 / 5199
# file :  29 / 5199
# file :  30 / 5199
# file :  31 / 5199
# file :  32 / 5199
# file :  33 / 5199
# file :  34 / 5199
# file :  35 / 5199
# file :  36 / 5199
# file :  37 / 5199
# file :  38 / 5199
# file :  39 / 5199
# file :  40 / 5199
# file :  41 / 5199
# file :  42 / 5199
# file :  43 / 5199
# file :  44 / 5199
# file :  45 / 5199
# file :  46 / 5199
# file :  47 / 5199
# file :  48 / 5199
# file :  49 / 5199
# file :  50 / 5199
# ...

# %%
# concat des X_datasets 

joined_X_data_rep = 'D:\\BUREAU\\corsESGI\\Projet_annuel\\X_dataset_joined\\'
X_data_rep = 'D:\\BUREAU\\corsESGI\\Projet_annuel\\X_datasets\\' 
X_data_files=[f for f in listdir(X_data_rep) if isfile(join(X_data_rep, f))]
X_data_files.sort(key=len)

ll= ['Latitude','Longitude','day_of_week','month','00:00:00-00:30:00','00:30:00-01:00:00','01:00:00-01:30:00','01:30:00-02:00:00','02:00:00-02:30:00','02:30:00-03:00:00','03:00:00-03:30:00','03:30:00-04:00:00','04:00:00-04:30:00','04:30:00-05:00:00','05:00:00-05:30:00','05:30:00-06:00:00','06:00:00-06:30:00','06:30:00-07:00:00','07:00:00-07:30:00','07:30:00-08:00:00','08:00:00-08:30:00','08:30:00-09:00:00','09:00:00-09:30:00','09:30:00-10:00:00','10:00:00-10:30:00','10:30:00-11:00:00','11:00:00-11:30:00','11:30:00-12:00:00','12:00:00-12:30:00','12:30:00-13:00:00','13:00:00-13:30:00','13:30:00-14:00:00','14:00:00-14:30:00','14:30:00-15:00:00','15:00:00-15:30:00','15:30:00-16:00:00','16:00:00-16:30:00','16:30:00-17:00:00','17:00:00-17:30:00','17:30:00-18:00:00','18:00:00-18:30:00','18:30:00-19:00:00','19:00:00-19:30:00','19:30:00-20:00:00','20:00:00-20:30:00','20:30:00-21:00:00','21:00:00-21:30:00','21:30:00-22:00:00','22:00:00-22:30:00','22:30:00-23:00:00','23:00:00-23:30:00','23:30:00-00:00:00']
res = pd.DataFrame(columns =ll)

def join_X_data(res):
    i=1
    for e in X_data_files:
        df = pd.read_csv(X_data_rep+e, sep=';')
        res = pd.concat([res,df], ignore_index=True)
        print( 'file : ', i,'/', len(X_data_files))
        i=i+1
    res.to_csv(joined_X_data_rep+"Last_X_dataset_merzouk.csv",index=False,sep=';')
    
join_X_data(res)
# Out:
# file :  1 / 2602
# file :  2 / 2602
# file :  3 / 2602
# file :  4 / 2602
# file :  5 / 2602
# file :  6 / 2602
# file :  7 / 2602
# file :  8 / 2602
# file :  9 / 2602
# file :  10 / 2602
# file :  11 / 2602
# file :  12 / 2602
# file :  13 / 2602
# file :  14 / 2602
# file :  15 / 2602
# file :  16 / 2602
# file :  17 / 2602
# file :  18 / 2602
# file :  19 / 2602
# file :  20 / 2602
# file :  21 / 2602
# file :  22 / 2602
# file :  23 / 2602
# file :  24 / 2602
# file :  25 / 2602
# file :  26 / 2602
# file :  27 / 2602
# file :  28 / 2602
# file :  29 / 2602
# file :  30 / 2602
# file :  31 / 2602
# file :  32 / 2602
# file :  33 / 2602
# file :  34 / 2602
# file :  35 / 2602
# file :  36 / 2602
# file :  37 / 2602
# file :  38 / 2602
# file :  39 / 2602
# file :  40 / 2602
# file :  41 / 2602
# file :  42 / 2602
# file :  43 / 2602
# file :  44 / 2602
# file :  45 / 2602
# file :  46 / 2602
# file :  47 / 2602
# file :  48 / 2602
# file :  49 / 2602
# file :  50 / 2602
# ...

# %% [markdown]
# # Tests et brouillon

# %%
# brouillon

#     ll= ['Latitude','Longitude','day_of_week','month','00:00:00-00:30:00','00:30:00-01:00:00','01:00:00-01:30:00','01:30:00-02:00:00','02:00:00-02:30:00','02:30:00-03:00:00','03:00:00-03:30:00','03:30:00-04:00:00','04:00:00-04:30:00','04:30:00-05:00:00','05:00:00-05:30:00','05:30:00-06:00:00','06:00:00-06:30:00','06:30:00-07:00:00','07:00:00-07:30:00','07:30:00-08:00:00','08:00:00-08:30:00','08:30:00-09:00:00','09:00:00-09:30:00','09:30:00-10:00:00','10:00:00-10:30:00','10:30:00-11:00:00','11:00:00-11:30:00','11:30:00-12:00:00','12:00:00-12:30:00','12:30:00-13:00:00','13:00:00-13:30:00','13:30:00-14:00:00','14:00:00-14:30:00','14:30:00-15:00:00','15:00:00-15:30:00','15:30:00-16:00:00','16:00:00-16:30:00','16:30:00-17:00:00','17:00:00-17:30:00','17:30:00-18:00:00','18:00:00-18:30:00','18:30:00-19:00:00','19:00:00-19:30:00','19:30:00-20:00:00','20:00:00-20:30:00','20:30:00-21:00:00','21:00:00-21:30:00','21:30:00-22:00:00','22:00:00-22:30:00','22:30:00-23:00:00','23:00:00-23:30:00','23:30:00-00:00:00']
#     res = pd.DataFrame(data=[],columns =ll)
    for e in files [2600 : 5200]:
        df = pd.read_csv ( train_path+ X_data_path +e, sep=';' )
        res= pd.concat([res,df])
        print( 'file : ', i,'/', len(files))
        i=i+1
    res.to_csv ('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\X_data\\X_batch_1.csv',index=False, sep=';' )
    res = res[0:0]  


    for e in files [ 5200:]:
        df = pd.read_csv ( train_path+ X_data_path +e, sep=';' )
        res= pd.concat([res,df])
        print( 'file : ', i,'/', len(files))
        i=i+1
    res.to_csv ('D:\\BUREAU\\corsESGI\\Projet_annuel\\Dataset_train_test_parts\\Batch_dataset\\Train\\X_data\\X_batch_2.csv',index=False, sep=';' )
    res = res[0:0]  

//////
place = df_nb_palaces[df_nb_palaces['id_horodateur']== int(e.split('.')[0])]['Nombre places réelles'].values
if len(place) == 0 :
    place = 0
else :
    place = place[0]

////

d=df_nb_palaces[df_nb_palaces['id_horodateur']== 4150402]['Nombre places réelles'].values
if len(d) ==0 :
    d=0
else :
    d=d[0]
d

/////


list_ind=rr[rr[tranche].sum(axis=1) ==0].index.tolist()
list_ind  = [ i for i in list_ind if i > 365]
rr=rr[~rr.index.isin(list_ind)]
gg=pd.DataFrame(data=rr[tranche].values.reshape((len(rr)*48),1).flatten().T,columns=['Target'])
gg=pd.DataFrame(data=rr[tranche].values.reshape((len(rr)*48),1).flatten().T,columns=['Target'])
gg

///


test=gg['Target'].values.tolist()
test.sort(reverse=True)
# test
/////



fp=df_nb_palaces['Nombre places réelles'].values.tolist()
fp.sort(reverse=True)
# fp



/////
